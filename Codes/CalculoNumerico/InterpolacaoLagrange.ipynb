# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def polinomioLagrange(xp, x, y, grau):
    yp = 0
    for k in range(0, n+1):
        produtorio = 1
        for i in range(0, n+1):
            if k != i:
                produtorio = produtorio * (xp - x[i])/(x[k] - x[i])
        yp = yp + produtorio*y[k]
    return yp

# Dados de Entrada

x = [2, 2.5, 4]
y = [0.5, 0.4, 0.25]

n = 2 # Grau do polinômio
xp = 3.5
yp = polinomioLagrange(xp, x, y, n)

ym = []
intervalo = np.arange(1.5, 5, 0.1)

for j in intervalo:
    ym.append(polinomioLagrange(j, x, y, n))

plt.figure()
plt.plot(intervalo, ym, 'b--', label = "Polinomio")
plt.plot(x, y, 'ro', label = "Pontos")
plt.plot(xp, yp, 'g*')
plt.grid()
plt.legend()
plt.show()
